# %%
import numpy as np
import torch
import torchvision
from torchvision import transforms
from torchinfo import summary
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, Subset
from sklearn.model_selection import train_test_split
import pandas as pd
import scipy.stats as stats
import math
from pathlib import Path
import zipfile
import os
import requests

#for data visualization
import seaborn as sns
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
import copy
import sys
# set_matplotlib_formats('svg')

# %%
#GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Download pizza, steak, sushi images from GitHub
data_path   = Path("data/")
image_path  = data_path / "pizza_steak_sushi"
image_url = "https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi.zip"
image_path.mkdir(parents=True, exist_ok=True)
target_file = Path(image_url).name
if(((image_path / 'train').exists)):
    pass
else:
    with open(data_path / target_file, "wb") as f:
            request = requests.get(image_url)
            print(f"[INFO] Downloading {target_file} from {image_url}...")
            f.write(request.content)
        
    # Unzip pizza, steak, sushi data
    with zipfile.ZipFile(data_path / target_file, "r") as zip_ref:
        print(f"[INFO] Unzipping {target_file} data...") 
        zip_ref.extractall(image_path)
    
    os.remove(data_path / target_file)

print(f'downloaded data to {image_path}')
# Out:
# downloaded data to data\pizza_steak_sushi

# %%
# Setup directory paths to train and test images
train_dir = image_path / "train"
test_dir = image_path / "test"

# %%
# from going_modular.going_modular import 
#   data_setup, 
#   engine

# from helper_functions import 
#   set_seeds, 
#   plot_loss_curves

# %%
print(os.gpu_count())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(os.gpu_count())
#
# AttributeError: module 'os' has no attribute 'gpu_count'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Dataset
#[Batch_size, height, width, color_channels] NHWC
#[Batch_size, color_channels, width, height] NCHW

# %%
# Data Loader
